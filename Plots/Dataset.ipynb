# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

dataset = pd.read_csv("C:/Users/sebaa/OneDrive/Studies/Thesis_RISE_2021/Thesis_ML_impl/labelled.csv")
print(dataset['class'].value_counts())
print(dataset['attack_type'].value_counts())
dataset['class'].value_counts().plot(kind='bar', xlabel='Class', ylabel ='Number of data samples')
dataset['attack_type'].value_counts().plot(kind='bar', xlabel='Attack type', ylabel ='Number of data samples')
# Out:
# normal     1920
# anomaly     785
# Name: class, dtype: int64
# nil                     1920
# Scaling                  434
# Data tampering           227
# DoS                       88
# False data injection      36
# Name: attack_type, dtype: int64
# <AxesSubplot:xlabel='Attack type', ylabel='Number of data samples'>
