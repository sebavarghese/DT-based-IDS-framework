# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('d6.csv')


def show_plot(_legend):
    plt.xticks(rotation=90)
    plt.ylim(ymin=0)
    axes.grid(True, color = 'lightgrey', lw = 0.5)
    if(_legend == True):
        plt.legend(('Actual','Expected'), loc = 'upper right', shadow=False, fancybox=True)
    plt.tight_layout()
    plt.show()

#PLOT 1 - LL bottle
fig, axes = plt.subplots(figsize=(18,18))
f1 = axes.plot(df['timestamp'], df['bottle_liquidlevel'],  marker = 'o', color = 'orange')
f2 = axes.plot(df['timestamp'], df['est_ll'], marker = 's', color = 'green', linestyle= '--')
axes.set_xlabel('Timestamp')
axes.set_ylabel('Liquid level in bottle')
show_plot(True)

#PLOT2 - LL tank
fig, axes = plt.subplots(figsize=(18,18))
f1 = axes.plot(df['timestamp'], df['tank_liquidlevel'],  marker = 'o', color = 'orange')
axes.set_xlabel('Timestamp')
axes.set_ylabel('Liquid level in tank')
_legend = False
show_plot(_legend)

#PLOT3 - flowlevel
fig, axes = plt.subplots(figsize=(18,18))
f1 = axes.plot(df['timestamp'], df['flowlevel'],  marker = 'o', color = 'orange')
f2 = axes.plot(df['timestamp'], df['est_fl'], marker = 's', color = 'green', linestyle='--')
axes.set_xlabel('Timestamp')
axes.set_ylabel('Flowlevel in pipe')
show_plot(True)

#PLOT4 - motor_status
fig, axes = plt.subplots(figsize=(18,18))
f1 = axes.plot(df['timestamp'], df['motor_status'],  marker = 'o', color = 'orange')
axes.set_xlabel('Timestamp')
axes.set_ylabel('Motor status')
_legend = False
show_plot(_legend)
